# %% [markdown]
# # 2021년 2학기 데이터시각화 중간고사
#
# - toc:flase
# - branch: master
# - badges: flase
# - comments: flase
# - author: 최규빈
# - hide: True
# - categories : [Visual]

# %%
import matplotlib.pyplot as plt 
import seaborn as sns 
from plotnine import * 
import cv2 
import numpy as np 
import pandas as pd

# %% [markdown]
# ### `1`. 다음은 이미지와 대응하는 히스토그램을 나타낸것이다. 이미지와 히스토그램을 올바르게 짝지어라. (5점)

# %% [markdown]
# - **답 : a-c, b-d**
# - a는 평활화가 되지 않은 히스토그램으로 특정 지점에 값이 몰려 있어 이미지 또한 명암이 뚜렷하지 않음 -> c그림의 히스토그램임.
# - b는 평활화된 히스토그램임. 이미지 또한 값이 비교적 고루 분포하게 되어 명암이 뚜렷해짐 -> d그림의 히스토그램임.

# %% [markdown]
# - 예시 a-c, b-d

# %% [markdown]
# ![](https://github.com/miruetoto/yechan/blob/master/_notebooks/mid_FIG1.png?raw=true)

# %% [markdown]
# ---

# %% [markdown]
# ### `2`. 주어진 자료를 바탕으로 예시와 같은 시각화를 구현하라. (5점)

# %% [markdown]
# **자료**
#
# ```python
# x=[1,2,3,4]
# y=[1,2,4,3]
# ```

# %% [markdown]
# **시각화예시**

# %% [markdown]
# ![](https://github.com/miruetoto/yechan/blob/master/_notebooks/mid_FIG2.png?raw=true)

# %% [markdown]
# ---

# %% [markdown]
# - **답**

# %%
x=[1,2,3,4]
y=[1,2,4,3]

# %%
_, axs = plt.subplots(2,2)  #2X2plot을 그리겠다
axs[0,0].plot(x,y,'o:b') 
axs[0,1].plot(x,y,'Xr') 
axs[1,0].plot(x,y,'xk') 
axs[1,1].plot(x,y,'.--m')

# %% [markdown]
# ---

# %% [markdown]
# ### `3`. 아래는 앤스콤의 플랏이다. 옳게 해석한 사람을 모두 고르라 (5점)

# %% [markdown]
# ![](https://github.com/miruetoto/yechan/blob/master/_notebooks/mid_FIG3.png?raw=true)

# %% [markdown]
# - **답** : 하니, 나애리, 홍두깨, 고은애
#
# (하니) 그림 (a)-(d)는 모두 양의 상관계수를 가진다.
#
# (나애리) 그림 (b)는 산점도가 직선이 아니라 곡선의 모양을 띄고 있으므로 상관계수는 0이다.
#
# (홍두깨) 그림 (c)에서 상단의 이상치를 제외하면 상관계수는 1이다.
#
# (고은애) 그림 (d)의 우측 이상치의 값을 적절하게 바꾸면 (d)의 상관계수를 음수로 만드는 것이 가능하다.
#
# (이창수) 그림 (c)역시 상단의 이상치 값을 적절하게 바꾸면 (c)의 상관계수를 음수로 만드는 것이 가능하다.

# %% [markdown]
# ---

# %% [markdown]
# ### `4`. 다음은 아이스크림 소비량과 소아마비의 관계를 그린 산점도이다. 이때 색깔은 온도가 비슷한 관측치로 그룹핑되었다. 옳은 해석을 모두 골라라. (10점)

# %% [markdown]
# ![](https://github.com/miruetoto/yechan/blob/master/_notebooks/mid_FIG4.png?raw=true)

# %% [markdown]
# - **답** : 하니, 홍두깨, 고은애
#
# (하니) 아이스크림과 소아마비는 양의 상관관계에 있다.
#
# (나애리) 상관계수의 값이 1에 가까울수록 아이스크림과 소아마비의 인과성이 명확하다고 볼 수 있다.
#
# (홍두깨) 비슷한 온도를 가진 관측치에서는 아이스크림과 소아마비의 상관계수가 0에 가깝다.
#
# (고은애) 온도를 통제하였을 경우 아이스크림과 소아마비의 상관계수가 0이므로 둘 사이의 인과성이 있다고 보긴 어렵다.

# %% [markdown]
# ---

# %% [markdown]
# ### `5`. FIFA22 (100점)

# %% [markdown]
# 아래의 코드를 활용하여 FIFA22의 자료를 불러온뒤 물음에 답하라.

# %% [markdown]
# ```python
# df=pd.read_csv('https://raw.githubusercontent.com/guebin/2021DV/master/_notebooks/2021-10-25-FIFA22_official_data.csv')
# ```

# %% [markdown]
# #### (a) `Loaned From`,`Marking` 열을 선택하는 코드를 작성하고 값을 확인하라.

# %%
df=pd.read_csv('https://raw.githubusercontent.com/guebin/2021DV/master/_notebooks/2021-10-25-FIFA22_official_data.csv')

# %%
df.columns
# Out:
# Index(['ID', 'Name', 'Age', 'Photo', 'Nationality', 'Flag', 'Overall',
#        'Potential', 'Club', 'Club Logo', 'Value', 'Wage', 'Special',
#        'Preferred Foot', 'International Reputation', 'Weak Foot',
#        'Skill Moves', 'Work Rate', 'Body Type', 'Real Face', 'Position',
#        'Jersey Number', 'Joined', 'Loaned From', 'Contract Valid Until',
#        'Height', 'Weight', 'Crossing', 'Finishing', 'HeadingAccuracy',
#        'ShortPassing', 'Volleys', 'Dribbling', 'Curve', 'FKAccuracy',
#        'LongPassing', 'BallControl', 'Acceleration', 'SprintSpeed', 'Agility',
#        'Reactions', 'Balance', 'ShotPower', 'Jumping', 'Stamina', 'Strength',
#        'LongShots', 'Aggression', 'Interceptions', 'Positioning', 'Vision',
#        'Penalties', 'Composure', 'Marking', 'StandingTackle', 'SlidingTackle',
#        'GKDiving', 'GKHandling', 'GKKicking', 'GKPositioning', 'GKReflexes',
#        'Best Position', 'Best Overall Rating', 'Release Clause',
# ...

# %%
df_a=df.loc[:,['Loaned From','Marking']]
df_a
# Out:
#       Loaned From  Marking
# 0             NaN      NaN
# 1             NaN      NaN
# 2             NaN      NaN
# 3             NaN      NaN
# 4             NaN      NaN
# ...           ...      ...
# 16705         NaN      5.0
# 16706         NaN      NaN
# 16707         NaN      NaN
# 16708         NaN      NaN
# 16709         NaN     15.0
#
# [16710 rows x 2 columns]

# %% [markdown]
# #### (b) 기존의 데이터프레임에서 `Loaned From`, `Marking`열을 제외하는 코드를 작성하라.

# %%
df_b=df.drop(['Loaned From','Marking'], axis=1)
df_b
# Out:
#            ID             Name  Age  \
# 0      212198  Bruno Fernandes   26
# 1      209658      L. Goretzka   26
# 2      176580        L. Suárez   34
# 3      192985     K. De Bruyne   30
# 4      224334         M. Acuña   29
# ...       ...              ...  ...
# 16705  240558    18 L. Clayton   17
# 16706  262846         �. Dobre   20
# 16707  241317   21 Xue Qinghao   19
# 16708  259646        A. Shaikh   18
# 16709  178453    07 A. Censori   17
#
#                                                   Photo Nationality  \
# 0      https://cdn.sofifa.com/players/212/198/22_60.png    Portugal
# 1      https://cdn.sofifa.com/players/209/658/22_60.png     Germany
# 2      https://cdn.sofifa.com/players/176/580/22_60.png     Uruguay
# 3      https://cdn.sofifa.com/players/192/985/22_60.png     Belgium
# 4      https://cdn.sofifa.com/players/224/334/22_60.png   Argentina
# ...                                                 ...         ...
# ...

# %% [markdown]
# #### (c) (b)의 결과에 `.dropna()`를 사용하여 결측치를 제거하는 코드를 작성하라. 몇개의 결측치가 제거되었는가?

# %%
df_c=df_b.dropna()
df_c
# Out:
#            ID             Name  Age  \
# 0      212198  Bruno Fernandes   26
# 1      209658      L. Goretzka   26
# 2      176580        L. Suárez   34
# 3      192985     K. De Bruyne   30
# 4      224334         M. Acuña   29
# ...       ...              ...  ...
# 16703  259718      F. Gebhardt   19
# 16704  251433          B. Voll   20
# 16706  262846         �. Dobre   20
# 16707  241317   21 Xue Qinghao   19
# 16708  259646        A. Shaikh   18
#
#                                                   Photo Nationality  \
# 0      https://cdn.sofifa.com/players/212/198/22_60.png    Portugal
# 1      https://cdn.sofifa.com/players/209/658/22_60.png     Germany
# 2      https://cdn.sofifa.com/players/176/580/22_60.png     Uruguay
# 3      https://cdn.sofifa.com/players/192/985/22_60.png     Belgium
# 4      https://cdn.sofifa.com/players/224/334/22_60.png   Argentina
# ...                                                 ...         ...
# ...

# %%
len(df_b)
# Out:
# 16710

# %%
len(df_c)
# Out:
# 14398

# %% [markdown]
# - **답** : 총 2312개의 결측치가 제거됨

# %% [markdown]
# #### (d) (c)의 결과에 아래의 코드를 활용하여 `Wage`의 값을 적절하게 변환하라.
#
# ```python
# ### 코드1
# def convert_currency(value):
#     floatvalue = 0.0
#     strvalue=""
#     if "M" in value:
#         strvalue=value.replace("M","").replace("€","")
#         floatvalue=float(float(strvalue)*1000000)
#     elif "K" in value:
#         strvalue=value.replace("K","").replace("€","")
#         floatvalue=float(float(strvalue)*1000)
#     else:
#         floatvalue=value.replace("€","")
#     return floatvalue
# ```
# - 코드출처: https://www.kaggle.com/talhademirezen/cost-effective-youth-players-fifa22

# %%
def convert_currency(value):
    floatvalue = 0.0
    strvalue=""
    if "M" in value:
        strvalue=value.replace("M","").replace("€","")
        floatvalue=float(float(strvalue)*1000000)
    elif "K" in value:
        strvalue=value.replace("K","").replace("€","")
        floatvalue=float(float(strvalue)*1000)
    else:
        floatvalue=value.replace("€","")
    return floatvalue

# %%
df_c.loc[:,'Wage']
#df.groupby('g').agg({'y':[np.mean,np.median,np.std,lambda x: np.max(x)-np.min(x)]})
# Out:
# 0        €250K
# 1        €140K
# 2        €135K
# 3        €350K
# 4         €45K
#          ...
# 16703     €650
# 16704     €950
# 16706     €550
# 16707     €700
# 16708     €500
# Name: Wage, Length: 14398, dtype: object

# %%
df_c['Wage_2']=df_c.agg({'Wage': lambda x: convert_currency(x)})
df_c.loc[:,'Wage_2']
# Out:
# /tmp/ipykernel_1778507/1978956935.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# 0        250000.0
# 1        140000.0
# 2        135000.0
# 3        350000.0
# 4         45000.0
#            ...
# 16703         650
# 16704         950
# 16706         550
# 16707         700
# 16708         500
# Name: Wage_2, Length: 14398, dtype: object

# %%
df_c
# Out:
#            ID             Name  Age  \
# 0      212198  Bruno Fernandes   26
# 1      209658      L. Goretzka   26
# 2      176580        L. Suárez   34
# 3      192985     K. De Bruyne   30
# 4      224334         M. Acuña   29
# ...       ...              ...  ...
# 16703  259718      F. Gebhardt   19
# 16704  251433          B. Voll   20
# 16706  262846         �. Dobre   20
# 16707  241317   21 Xue Qinghao   19
# 16708  259646        A. Shaikh   18
#
#                                                   Photo Nationality  \
# 0      https://cdn.sofifa.com/players/212/198/22_60.png    Portugal
# 1      https://cdn.sofifa.com/players/209/658/22_60.png     Germany
# 2      https://cdn.sofifa.com/players/176/580/22_60.png     Uruguay
# 3      https://cdn.sofifa.com/players/192/985/22_60.png     Belgium
# 4      https://cdn.sofifa.com/players/224/334/22_60.png   Argentina
# ...                                                 ...         ...
# ...

# %% [markdown]
# #### (e) 아래의 세부사항에 맞춰서 `Best Position`에 따른 시장가치(`Value`)의 평균을 barplot을 이용하여 시각화 하라.

# %% [markdown]
# ***세부사항***
#
# - x축을 `Best Position`으로 하고 y축은 `Value`의 평균으로 할 것
# - `Value`가 가장 높은 3개의 포지션을 다른색으로 하이라이팅 할 것

# %% [markdown]
# ***힌트***
#
# - (d)의 코드를 활용해야함.
# - `Value`의 자료형이 object 일 경우 정상적으로 수치연산이 되지 않을 수 있으니 `~.astype(float)`를 활용하여 자료형을 변환할 것.

# %%
df_c.loc[:,'Value']
# Out:
# 0        €107.5M
# 1           €93M
# 2         €44.5M
# 3        €125.5M
# 4           €37M
#           ...
# 16703      €170K
# 16704      €375K
# 16706      €180K
# 16707      €100K
# 16708      €110K
# Name: Value, Length: 14398, dtype: object

# %%
df_c['Value_2']=df_c.agg({'Value': lambda x: convert_currency(x)})
# Out:
# /tmp/ipykernel_1778507/1333677254.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df_c.loc[:, 'Value_2']
# Out:
# 0        107500000.0
# 1         93000000.0
# 2         44500000.0
# 3        125500000.0
# 4         37000000.0
#             ...
# 16703       170000.0
# 16704       375000.0
# 16706       180000.0
# 16707       100000.0
# 16708       110000.0
# Name: Value_2, Length: 14398, dtype: float64

# %%
df_c.loc[:, 'Value_2'].dtypes
# Out:
# dtype('float64')

# %%
df_e=df_c.groupby('Best Position').agg({'Value_2' : 'mean'})
df_e=df_e.sort_values(by='Value_2',ascending=False).reset_index()
df_e['Class']=(['True']*3+['False']*12)
df_e
# Out:
#    Best Position       Value_2  Class
# 0             CF  9.122222e+06   True
# 1             LW  6.443137e+06   True
# 2             CM  5.630414e+06   True
# 3            CAM  4.356162e+06  False
# 4             RW  3.977832e+06  False
# 5            CDM  3.539740e+06  False
# 6            LWB  3.451340e+06  False
# 7             LM  3.439977e+06  False
# 8             ST  3.295080e+06  False
# 9             RB  3.203283e+06  False
# 10            LB  3.051887e+06  False
# 11            CB  3.038834e+06  False
# 12           RWB  3.023522e+06  False
# 13            GK  2.703686e+06  False
# 14            RM  2.550153e+06  False

# %%
ggplot(df_e)+geom_bar(aes(x='Best Position', y='Value_2', fill='Class'),stat='identity')
# Out:
# <ggplot: (8737580116968)>

# %% [markdown]
# ***시각화예시***

# %% [markdown]
# ![](https://github.com/miruetoto/yechan/blob/master/_notebooks/mid_FIG5_1.png?raw=true)

# %% [markdown]
# #### (f) 아래의 세부사항에 맞추어 (`Dribbling`,`SlidingTackle`)의 산점도를 그려라.

# %% [markdown]
# ***세부사항***
#
# (i) `Best Position`의 값을 바탕으로 면분할을 하라.
#
# (ii) `Age`를 색으로 표현하라.
#
# (iii) 산점도의 투명도는 `alpha=0.5`로 `size=0.5`로 설정할 것.

# %%
ggplot(df_c)+geom_point(aes(x='Dribbling', y='SlidingTackle', color='Age'),alpha=0.5, size=0.5, stat='identity')\
+facet_wrap('Best Position')
# Out:
# <ggplot: (8737580068852)>

# %% [markdown]
# ![](https://github.com/miruetoto/yechan/blob/master/_notebooks/mid_FIG5_2.png?raw=true)

# %% [markdown]
# #### (g) (f)의 그림을 올바르게 해석한 사람은?

# %% [markdown]
# - **답** : 하니, 홍두깨, 고은애
#
# (하니) 포지션 `GK`에 있는 선수는 `Dribbling`, `SlidingTackle` 값이 다른포지션대비 상대적으로 낮다.
#
# (나애리) 모든 포지션에서 `Dribbling`, `SlidingTackle`은 서로 독립이라 볼 수 있다.
#
# (홍두깨) 포지션 `CAM`은 나이와 `Dribbling` 사이에 양의 상관관계에 있다.
#
# (고은애) 포지션 `CB`은 나이와 `Dribbling` 사이에 상관계수가 거의 0이다.

# %% [markdown]
# ---

# %% [markdown]
# ## 못 푼 문제 다시 풀어본 것

# %% [markdown]
# #### (h) `Best Position`이 "CAM" 혹은 "CB"인 플레이어만 골라서 (`Dribbling`,`SlidingTackle`)의 산점도를 그려라.

# %% [markdown]
# ***세부사항***
#
# - x축: Dribbling, y축: SlidingTackle 로 설정
# - Value에 따라 점의 크기를 다르게 설정
# - 나이에 따라 색깔을 다르게 설정

# %%
df_h=df_c[df_c['Best Position'].str.contains('CAM|CB')]

# %%
df_h
# Out:
#            ID             Name  Age  \
# 0      212198  Bruno Fernandes   26
# 11     226161  Marcos Llorente   26
# 12     155862     Sergio Ramos   35
# 13     197445         D. Alaba   29
# 30     230767   Renato Sanches   23
# ...       ...              ...  ...
# 15666  262759         S. Black   19
# 15722  261988        S. Grehan   17
# 15799  252561         Zhang Yu   18
# 15817  262041       P. Maguire   18
# 15869  239427      21 A. Ajeti   23
#
#                                                   Photo          Nationality  \
# 0      https://cdn.sofifa.com/players/212/198/22_60.png             Portugal
# 11     https://cdn.sofifa.com/players/226/161/22_60.png                Spain
# 12     https://cdn.sofifa.com/players/155/862/22_60.png                Spain
# 13     https://cdn.sofifa.com/players/197/445/22_60.png              Austria
# 30     https://cdn.sofifa.com/players/230/767/22_60.png             Portugal
# ...

# %%
ggplot(df_h)+geom_point(aes(x='Dribbling', y='SlidingTackle', size='Value_2', color='Age'),alpha=0.4, stat='identity')+facet_wrap('Best Position')
# Out:
# <ggplot: (8737578789235)>

# %% [markdown]
# ***시각화예시***

# %% [markdown]
# ![](https://github.com/miruetoto/yechan/blob/master/_notebooks/mid_FIG5_3.png?raw=true)

# %% [markdown]
# ---

# %% [markdown]
# #### (i) 그림 (h)를 올바르게 해석한것을 모두 고르라.

# %% [markdown]
# -**답** : 하니, 홍두깨, 고은애
#
# (하니) `AGE`와 `Value`는 양의 상관관계에 있다.
#
# (나애리) 따라서 축구선수는 `AGE`가 증가함 따라 `Value`가 올라가는 것을 알 수 있다. 즉 `AGE`와 `Value`사이에는 인과성이 있다.
#
# (홍두깨) 포지션 `CAM`은 `Dribbiling` 능력과 `Value`가 양의 상관관계에 있어보인다.
#
# (고은애) 반면에 포지션 `CB`는 `Dribbling` 능력보다는 `SlidingTackle`이 `Value`와 양의 상관관계에 있다고 볼 수 있다.

# %% [markdown]
# ----

# %% [markdown]
# ## 못 푼 문제 다시풀기

# %% [markdown]
# ### `6`. 하니의 산책경로 (40점)

# %% [markdown]
# 공원에서 뛰는것을 좋아하는 강아지 하니가 있다. 아래는 강아지 하니가 주인과 함께 공원을 산책한 경로이다. 산책코스는 아래와 같이 집에서 공원으로 가는 A코스와 공원에서 집으로 오는 B코스로 나누어진다.
#
# `-` A코스: 집 $\to$ 카페 $\to$ 초등학교 정문  $\to$ 공원
#
# `-` B코스: 공원 $\to$ 초등학교 후문 $\to$ 동물병원 $\to$ 집
#
# 각 위치의 좌표는 아래와 같다.
#
# - 집: (0,0)
# - 카페: (1,2)
# - 초등학교 정문: (4,3)
# - 공원: (5,5)
# - 초등학교 후문: (4.1,3)
# - 동물병원: (1,0.5)
#
# 집에서 출발시에 하니의 체력은 100이며, 각 중간지점에서 하니의 체력은 이동거리에 비례하여 감소한다고 하자. 예를들어 A코스-카페에서 하니의 체력은 아래와 같이 계산할 수 있다.
#
# - $100- \sqrt{1^2+2^2}$
#
# 또한 하니는 공원정문에서 달리기를 시작하였고 (**b코스 시작**) 이후에 70의 체력을 소진한뒤 공원후문에 도착하였다고 하자. (즉 공원정문에서하니의 체력이 $x$ 라면 공원후문에서 하니의 체력은 $x-70$ 이다.)
#
# 하니의 이동경로에 따른 체력의 변화를 시각화 하라.

# %%
x1=np.array([0,1,4,5])
y1=np.array([0,2,3,5])
x2=np.array([5,4.1,1,0])
y2=np.array([5,3,0.5,0])

# %%
place1=['집']+['카페']+['초등정문']+['공원']
place2=['공원']+['초등후문']+['병원']+['집']
course1=['A']*4
course2=['B']*4
walk1=pd.DataFrame({'x':x1,'y':y1, 'place':place1, 'course':course1})
walk2=pd.DataFrame({'x':x2,'y':y2, 'place':place2, 'course':course2})

# %%
walk1['stamina']=np.sqrt((x1*x1)+(y1*y1))
walk2['stamina']=np.sqrt((x2*x2)+(y2*y2))

# %%
sum=0
for i in walk1['stamina']:
    sum += i
    print(-sum)
# Out:
# -0.0
# -2.23606797749979
# -7.23606797749979
# -14.307135789365265

# %%
sum=0
for i in walk2['stamina']:
    sum += i
    print(-sum)
# Out:
# -7.0710678118654755
# -12.15142213021769
# -13.269456118967584
# -13.269456118967584

# %%
walk1
# Out:
#    x  y place course   stamina stamina_2
# 0  0  0     집      A  0.000000      None
# 1  1  2    카페      A  2.236068      None
# 2  4  3  초등정문      A  5.000000      None
# 3  5  5    공원      A  7.071068      None

# %%
walk2
# Out:
#      x    y place course   stamina
# 0  5.0  5.0    공원      B  7.071068
# 1  4.1  3.0  초등후문      B  5.080354
# 2  1.0  0.5    병원      B  1.118034
# 3  0.0  0.0     집      B  0.000000

# %%
pd.concat([walk1, walk2], axis = 0).reset_index()
# Out:
#    index    x    y place course   stamina stamina_2
# 0      0  0.0  0.0     집      A  0.000000      None
# 1      1  1.0  2.0    카페      A  2.236068      None
# 2      2  4.0  3.0  초등정문      A  5.000000      None
# 3      3  5.0  5.0    공원      A  7.071068      None
# 4      0  5.0  5.0    공원      B  7.071068       NaN
# 5      1  4.1  3.0  초등후문      B  5.080354       NaN
# 6      2  1.0  0.5    병원      B  1.118034       NaN
# 7      3  0.0  0.0     집      B  0.000000       NaN

# %%
ggplot(walk)+geom_line(aes(x='x',y='y',color='course',size='stamina'),alpha=0.5,stat='identity')+geom_point(aes(x='x',y='y'),stat='identity')
# Out:
# <ggplot: (8737576540501)>

# %% [markdown]
# **시각화예시**

# %% [markdown]
# ![](https://github.com/miruetoto/yechan/blob/master/_notebooks/mid_FIG6.png?raw=true)

# %% [markdown]
# ----

# %% [markdown]
# ### `7`. 빈칸에 적절한 값을 채워 심슨의 역설을 설명하는 예제를 완성하고 시각화 하라. (30점)

# %% [markdown]
# 다음은 농구선수 A,B의 시즌별 자유투 성공률이다.

# %% [markdown]
# | |시즌1|시즌2|
# |:-:|:-:|:-:|
# |A선수|7/10|?|
# |B선수|?|4/4|
# * 표안의 값은 성공횟수/총자유투시도

# %% [markdown]
# ?에 적절한 값을 채워 시즌 1,2 모두 B선수의 자유투 성공률이 높지만 시즌1-2를 전체 합치면 A선수의 자유투 성공률이 더 높도록 하라. (즉 ?에 적절한 값을 채워 심슨의 역설을 섦영하기 위한 자료를 구성하라.)
#
# 만들어진 자료를 바탕으로 심슨의 역설을 시각화하라. (즉 시즌 1,2의 자유투 성공률과 전체 자유트 성공률을 barplot으로 시각화하라)

# %%
season=(['s1']*2+['s2']*2)*2
player=(['A']*4+['B']*4)
goal=(['pass']+['fail'])*4
score=[7,3,18,2,20,6,4,0]
#fail=[3,2,9,0]
#total=[10,4,10,4]
df=pd.DataFrame({'season':season,'player':player,'goal':goal, 'score':score})
df
# Out:
#   season player  goal  score
# 0     s1      A  pass      7
# 1     s1      A  fail      3
# 2     s2      A  pass     18
# 3     s2      A  fail      2
# 4     s1      B  pass     20
# 5     s1      B  fail      6
# 6     s2      B  pass      4
# 7     s2      B  fail      0

# %%
df1=df.groupby(['season','player']).agg({'score':np.sum}).reset_index().rename(columns={'score':'total'})

# %%
df1
# Out:
#   season player  total
# 0     s1      A     10
# 1     s1      B     26
# 2     s2      A     20
# 3     s2      B      4

# %%
df2=df.groupby(['season','player','goal']).agg({'score':np.sum}).reset_index()

# %%
df2
# Out:
#   season player  goal  score
# 0     s1      A  fail      3
# 1     s1      A  pass      7
# 2     s1      B  fail      6
# 3     s1      B  pass     20
# 4     s2      A  fail      2
# 5     s2      A  pass     18
# 6     s2      B  fail      0
# 7     s2      B  pass      4

# %%
df3=pd.merge(df1,df2)
df3
# Out:
#   season player  total  goal  score
# 0     s1      A     10  fail      3
# 1     s1      A     10  pass      7
# 2     s1      B     26  fail      6
# 3     s1      B     26  pass     20
# 4     s2      A     20  fail      2
# 5     s2      A     20  pass     18
# 6     s2      B      4  fail      0
# 7     s2      B      4  pass      4

# %%
df3['prop']=df3.score/df3.total
df3
# Out:
#   season player  total  goal  score      prop
# 0     s1      A     10  fail      3  0.300000
# 1     s1      A     10  pass      7  0.700000
# 2     s1      B     26  fail      6  0.230769
# 3     s1      B     26  pass     20  0.769231
# 4     s2      A     20  fail      2  0.100000
# 5     s2      A     20  pass     18  0.900000
# 6     s2      B      4  fail      0  0.000000
# 7     s2      B      4  pass      4  1.000000

# %%
df4=df3.groupby(['player','goal']).agg({'score':np.sum}).reset_index()
df4
# Out:
#   player  goal  score
# 0      A  fail      5
# 1      A  pass     25
# 2      B  fail      6
# 3      B  pass     24

# %%
df5=df3.groupby(['player']).agg({'score':np.sum}).reset_index().rename(columns={'score':'total'})
df5
# Out:
#   player  total
# 0      A     30
# 1      B     30

# %%
df6=pd.merge(df4,df5)
df6
# Out:
#   player  goal  score  total
# 0      A  fail      5     30
# 1      A  pass     25     30
# 2      B  fail      6     30
# 3      B  pass     24     30

# %%
df6['prop']=df6.score/df6.total
df6
# Out:
#   player  goal  score  total      prop
# 0      A  fail      5     30  0.166667
# 1      A  pass     25     30  0.833333
# 2      B  fail      6     30  0.200000
# 3      B  pass     24     30  0.800000

# %%
ggplot(df6.query('goal=="pass"'))+geom_bar(aes(x='player',y='prop',fill='player'),stat='identity')
# Out:
# <ggplot: (8737579636074)>

# %%
ggplot(df3.query('goal=="pass"'))+geom_bar(aes(x='player',y='prop',fill='player'),stat='identity')+facet_wrap('season')
# Out:
# <ggplot: (8737579599017)>
