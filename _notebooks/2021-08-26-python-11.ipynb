# %% [markdown]
# # (공부) 데이터시각화
# > 작성완료
#
# - toc:true
# - branch: master
# - badges: true
# - comments: true
# - author: kimha02
# - categories: [Python]

# %% [markdown]
# ## matplotlib: 벡터친화적인 시각화

# %% [markdown]
# ### 예제1

# %%
! pip install matplotlib   #패키지 설치
# Out:
# Requirement already satisfied: matplotlib in /home/khy/anaconda3/envs/py38r40/lib/python3.8/site-packages (3.4.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/khy/anaconda3/envs/py38r40/lib/python3.8/site-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /home/khy/anaconda3/envs/py38r40/lib/python3.8/site-packages (from matplotlib) (0.10.0)
# Requirement already satisfied: python-dateutil>=2.7 in /home/khy/anaconda3/envs/py38r40/lib/python3.8/site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: pillow>=6.2.0 in /home/khy/anaconda3/envs/py38r40/lib/python3.8/site-packages (from matplotlib) (8.3.1)
# Requirement already satisfied: numpy>=1.16 in /home/khy/anaconda3/envs/py38r40/lib/python3.8/site-packages (from matplotlib) (1.21.1)
# Requirement already satisfied: pyparsing>=2.2.1 in /home/khy/anaconda3/envs/py38r40/lib/python3.8/site-packages (from matplotlib) (2.4.7)
# Requirement already satisfied: six in /home/khy/anaconda3/envs/py38r40/lib/python3.8/site-packages (from cycler>=0.10->matplotlib) (1.16.0)

# %%
import matplotlib.pyplot as plt

# %%
x=[1,2,3,4]
y=[1,2,3,2]

# %%
plt.plot(x,y,'x')  ### 'x'는 모양

# %%
y2=[1.1,2.1,3.2,1]

# %%
plt.plot(x,y,':o')
plt.plot(x,y2,':o')

# %% [markdown]
# #### 예제2

# %%
import pandas as pd

# %%
dfdata=pd.read_csv("dfdata[1].csv")

# %%
dfdata.head()
# Out:
#    toeic  gpa employed company  salary
# 0    400  4.2        N       -       0
# 1    445  2.2        N       -       0
# 2    440  3.4        N       -       0
# 3    490  3.8        N       -       0
# 4    520  4.1        Y       K    5000

# %%
plt.plot(dfdata.toeic,dfdata.gpa,'o') #x=toeic, y=gpa, shape='o'

# %% [markdown]
# `-` 색깔로 그룹 구분하기

# %%
toeic_y=dfdata.query('employed=="Y"').toeic   #채용된 사람들의 토익점수
toeic_n=dfdata.query('employed=="N"').toeic   #채용 안 된 사람들의 토익점수
gpa_y=dfdata.query('employed=="Y"').gpa   #채용된 사람들의 성적
gpa_n=dfdata.query('employed=="N"').gpa   #채용 안 된 사람들의 성적
plt.plot(toeic_y,gpa_y,'o')  #Blue Point
plt.plot(toeic_n,gpa_n,'o')  #Orange Point

# %% [markdown]
# `-` 그런데 과정이 좀 복잡해보인다.
# > 과정 : 데이터프레임 -> 쿼리문 -> 필터링된 데이터 프레임 -> 벡터화 -> 저장 -> 플랏
# 데이터 프레임을 벡터화하여 플랏하는 과정은 필수적인데 좀 귀찮다.
# **★ 바로 플랏하는 방법을 알아보자!**

# %% [markdown]
# -------

# %% [markdown]
# ## seaborn: 데이터프레임 친화적인 시각화

# %% [markdown]
# ### 예제2 (이어서)

# %%
import seaborn as sns

# %% [markdown]
# `-` 아까 그린 Blue, Orange 그림을 그려보자.

# %%
sns.relplot(data=dfdata, x='toeic',y='gpa',hue='employed')  #범례도 생긴다. hue에 그룹핑하고 싶은 변수 입력

# %% [markdown]
# `–` 취업된 사람들이 각각 어떠한 회사에 갔는지 궁금하다.

# %%
sns.relplot(data=dfdata.query('employed=="Y"'), x='toeic',y='gpa',hue='company')

# %% [markdown]
# `-` 연봉정보도 한눈에 알아보기 쉽게 그리고 싶다면?

# %%
sns.relplot(data=dfdata.query('employed=="Y"'), x='toeic',y='gpa',hue='company',size='salary')

# %% [markdown]
# --------------------

# %% [markdown]
# ## 객체지향적 인터페이스
# `-` 위에서 까지 진행한 것은 함수에 값을 입력하면 함수가 알아서 실행되어 플랏을 그리는 방식임 -> 데이터 전처리 계획 등이 필요함
# `-` 객체지향적 인터페이스는 그림을 보며 하나씩 만들어가는 느낌 -> 자유도가 높다!

# %%
p1=plt.figure()

# %%
p1

# %%
p1.axes
# Out:
# []

# %%
p1.add_axes([0,0,1,1])  #(0,0)위치에 가로세로 길이가 1인 축을 만들어라
# Out:
# <Axes:>

# %%
p1   #축 1개 생성

# %%
p1.add_axes([0,1,1,1])
# Out:
# <Axes:>

# %%
p1.axes
# Out:
# [<Axes:>, <Axes:>]

# %%
p1

# %%
p1.add_axes([0.5,0.5,1,1])  #(0.5,0.5)위치에 가로세로 길이가 1인 축을 만들어라
# Out:
# <Axes:>

# %%
p1.axes
# Out:
# [<Axes:>, <Axes:>, <Axes:>]

# %%
p1

# %%
p1.axes[0].plot(x,y)  #가장 처음 만든 면에 plot

# %%
p1

# %%
p1.axes[2].plot(x,y,'o') #3번째 면에 plot

# %%
p1

# %%
p1.axes[2].plot(x,y2,':o')

# %%
p1
